# %% [markdown]
# <a href="https://colab.research.google.com/github/XDMickeyYau/CSC2529-Project/blob/selfDZSR/SelfDZSR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/XDMickeyYau/SelfDZSR.git
# Out:
# fatal: destination path 'SelfDZSR' already exists and is not an empty directory.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp -r ./drive/MyDrive/CameraFusion  ./SelfDZSR

# %%
# !cp -r ./drive/MyDrive/CUFDE5  ./SelfDZSR

# %%
# !mkdir ./SelfDZSR/CUFDE5/CameraFusion

# %%
# !cp -r ./SelfDZSR/CUFDE5/CUFDE5_HR/ ./SelfDZSR/CUFDE5/CameraFusion/test_HR

# %%
# !cp -r ./SelfDZSR/CUFDE5/CUFDE5_LR_x4/ ./SelfDZSR/CUFDE5/CameraFusion/test_LR

# %%
# !pip install colour_demosaicing tensorboardX lpips
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
! cd SelfDZSR/ && sh test_CUFDE5.sh
# Out:
# Start to test the model....
# ----------------- Options ---------------
#                FLOPs_only: False
#                     alpha: 0.99
#                batch_size: 16
#                     beta1: 0.9
#                     beta2: 0.999
#                block_mode: CRC
#                 calc_psnr: False
#                    camera: nikon
#           checkpoints_dir: ./ckpt
#                      chop: True                          	[default: False]
#                  dataroot: ./CUFDE5/                     	[default: ]
#              dataset_name: cam                           	[default: ['eth']]
#                 drop_last: True
#                   dropout: 0.3
#                  finetune: False
#             finetune_name: None
#                  full_res: True                          	[default: False]
#                   gpu_ids: 0                             	[default: all]
#                     imlib: cv2
#                 init_gain: 0.02
# ...
