# %% [markdown]
# <a href="https://colab.research.google.com/github/XDMickeyYau/CSC2529-Project/blob/selfDZSR/SelfDZSR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -e git+https://github.com/XDMickeyYau/SelfDZSR.git@package#egg=SelfDZSR
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining SelfDZSR from git+https://github.com/XDMickeyYau/SelfDZSR.git@package#egg=SelfDZSR
#   Cloning https://github.com/XDMickeyYau/SelfDZSR.git (to revision package) to ./src/selfdzsr
#   Running command git clone -q https://github.com/XDMickeyYau/SelfDZSR.git /content/src/selfdzsr
#   Running command git checkout -b package --track origin/package
#   Switched to a new branch 'package'
#   Branch 'package' set up to track remote branch 'package' from 'origin'.
# ...
#   Running setup.py develop for SelfDZSR
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp -r ./drive/MyDrive/CUFDE5  ./src/selfdzsr

# %%
# !mkdir ./src/selfdzsr/CUFDE5/CameraFusion

# %%
# !cp -r ./src/selfdzsr/CUFDE5/CUFDE5_HR/ ./src/selfdzsr/CUFDE5/CameraFusion/test_HR

# %%
# !cp -r ./src/selfdzsr/CUFDE5/CUFDE5_LR_x4/ ./src/selfdzsr/CUFDE5/CameraFusion/test_LR

# %%
# !pip install colour_demosaicing tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 125 kB 29.8 MB/s
# ...

# %%
# %%sh
# #!/bin/bash
# echo "Start to test the model...."
#
# dataroot="./src/selfdzsr/CUFDE5"
# name="camerafusion_l1" # You can replace 'camerafusion_l1' with 'camerafusion_l1sw' when testing the model trained by SW loss.
# scale='2'
# data='cam'
# cam='True'
# device="0"
# iter="401"
#
# python ./src/selfdzsr/test.py \
#     --model refsr  --name $name  --dataset_name $data  --chop True  --full_res True  --predict True \
#     --load_iter $iter    --save_imgs True  --calc_psnr False  --gpu_ids $device  --scale $scale  --dataroot $dataroot
# echo "metric"
# python ./src/selfdzsr/test.py  --device $device --name $name --load_iter $iter  --cam $cam  --dataroot $dataroot
# Out:
# Start to test the model....
# ----------------- Options ---------------
#                FLOPs_only: False
#                     alpha: 0.99
#                batch_size: 16
#                     beta1: 0.9
#                     beta2: 0.999
#                block_mode: CRC
#                 calc_psnr: False
#                    camera: nikon
#           checkpoints_dir: ./ckpt
#                      chop: True                          	[default: False]
#                  dataroot: ./src/selfdzsr/CUFDE5         	[default: ]
#              dataset_name: cam                           	[default: ['eth']]
#                 drop_last: True
#                   dropout: 0.3
#                  finetune: False
#             finetune_name: None
#                  full_res: True                          	[default: False]
#                   gpu_ids: 0                             	[default: all]
#                     imlib: cv2
#                 init_gain: 0.02
# ...
